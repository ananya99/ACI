# %%
lon_ranges = [
    (-14.156859241940158, 144.00943250203338),
    (-67.14814885829009, 118.99176724312127),
    (-19.151868531901762, 67.2269944866738),
    (-68.69522545361816, 111.82671075192431),
    (-125.57381799685213, 142.1723191046721),
    (-112.22164715731259, 161.46923062399932),
    (-78.90396284206236, 126.57045089061272),
    (-96.03138543174703, 138.0184136782104),
    (-39.31973004948928, 108.92145375664676),
    (-103.09434411085132, 73.87883007770687),
    (-102.13854994495978, 155.2954041537795),
    (-73.32044526158671, 79.92308889805216)
]

fitness_values = [14.359993, 0.4599947999999996, 0.6999966000000004, 3.0199938000000004, -4.4599994999999995, -1.620006, 1.9399945, 1.9399945, 0.5799953999999996, 1.7199948000000012, -0.1800058, -10.4800028]

print("Number of longitude ranges:", len(lon_ranges))
print("\nFirst few ranges:")
for i, (start, end) in enumerate(lon_ranges[:3]):
    print(f"Range {i+1}: {start} to {end}")
    
gen1 = lon_ranges[:4]
gen2 = lon_ranges[4:8]
gen3 = lon_ranges[8:12]

lon_range_min = [min(lon_ranges[i][0], lon_ranges[i][1]) for i in range(len(lon_ranges))]

import matplotlib.pyplot as plt

# plot fitness values against lon_range_min
plt.plot(lon_range_min, fitness_values)
plt.xlabel("Lon Range Min")
plt.ylabel("Fitness Value")
plt.show()
# Out:
# Number of longitude ranges: 12
#
# First few ranges:
# Range 1: -14.156859241940158 to 144.00943250203338
# Range 2: -67.14814885829009 to 118.99176724312127
# Range 3: -19.151868531901762 to 67.2269944866738

# %%
import matplotlib.pyplot as plt

lon_ranges = [
    (-14.156859241940158, 144.00943250203338),
    (-67.14814885829009, 118.99176724312127),
    (-19.151868531901762, 67.2269944866738),
    (-68.69522545361816, 111.82671075192431),
    (-125.57381799685213, 142.1723191046721),
    (-112.22164715731259, 161.46923062399932),
    (-78.90396284206236, 126.57045089061272),
    (-96.03138543174703, 138.0184136782104),
    (-39.31973004948928, 108.92145375664676),
    (-103.09434411085132, 73.87883007770687),
    (-102.13854994495978, 155.2954041537795),
    (-73.32044526158671, 79.92308889805216)
]

fitness_values = [14.359993, 0.4599947999999996, 0.6999966000000004, 3.0199938000000004, -4.4599994999999995, -1.620006, 1.9399945, 1.9399945, 0.5799953999999996, 1.7199948000000012, -0.1800058, -10.4800028]


lon_ranges_min = [min(abs(lon_ranges[i][0]), abs(lon_ranges[i][1])) for i in range(len(lon_ranges))]

# Create figure and axis
plt.figure(figsize=(10, 6))

# Plot points for generation 1
gen1_indices = range(4)  # First 7 points are from generation 1
plt.plot([r for r in lon_ranges_min[:4]], fitness_values[:4], 'b-', alpha=0.3)  # Line
plt.scatter([r for r in lon_ranges_min[:4]], fitness_values[:4], 
           c='blue', label='Generation 1', alpha=0.6)
# plt.scatter([r for r in lon_ranges_min[:4]], fitness_values[:4], 
#            c='blue', label='Generation 1', alpha=0.6)

# Plot points for generation 2
gen2_indices = range(4, 8)  # Last 4 points are from generation 2
plt.plot([r for r in lon_ranges_min[4:8]], fitness_values[4:8], 'r-', alpha=0.3)  # Line
plt.scatter([r for r in lon_ranges_min[4:8]], fitness_values[4:8], 
           c='red', label='Generation 2', alpha=0.6)

# Plot points for generation 3
gen3_indices = range(8, 12)  # Last 4 points are from generation 2
plt.plot([r for r in lon_ranges_min[8:12]], fitness_values[8:12], 'g-', alpha=0.3)  # Line
plt.scatter([r for r in lon_ranges_min[8:12]], fitness_values[8:12], 
           c='green', label='Generation 3', alpha=0.6)

plt.xlabel("Longitude Range Minimum")
plt.ylabel("Fitness Value")
plt.title("Fitness Values vs Longitude Range Minimum by Generation")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
